# %%
#****************************************************************************
# (C) Cloudera, Inc. 2020-2023
#  All rights reserved.
#
#  Applicable Open Source License: GNU Affero General Public License v3.0
#
#  NOTE: Cloudera open source products are modular software products
#  made up of hundreds of individual components, each of which was
#  individually copyrighted.  Each Cloudera open source product is a
#  collective work under U.S. Copyright Law. Your license to use the
#  collective work is as provided in your written agreement with
#  Cloudera.  Used apart from the collective work, this file is
#  licensed for your use pursuant to the open source license
#  identified above.
#
#  This code is provided to you pursuant a written agreement with
#  (i) Cloudera, Inc. or (ii) a third-party authorized to distribute
#  this code. If you do not have a written agreement with Cloudera nor
#  with an authorized and properly licensed third party, you do not
#  have any rights to access nor to use this code.
#
#  Absent a written agreement with Cloudera, Inc. (“Cloudera”) to the
#  contrary, A) CLOUDERA PROVIDES THIS CODE TO YOU WITHOUT WARRANTIES OF ANY
#  KIND; (B) CLOUDERA DISCLAIMS ANY AND ALL EXPRESS AND IMPLIED
#  WARRANTIES WITH RESPECT TO THIS CODE, INCLUDING BUT NOT LIMITED TO
#  IMPLIED WARRANTIES OF TITLE, NON-INFRINGEMENT, MERCHANTABILITY AND
#  FITNESS FOR A PARTICULAR PURPOSE; (C) CLOUDERA IS NOT LIABLE TO YOU,
#  AND WILL NOT DEFEND, INDEMNIFY, NOR HOLD YOU HARMLESS FOR ANY CLAIMS
#  ARISING FROM OR RELATED TO THE CODE; AND (D)WITH RESPECT TO YOUR EXERCISE
#  OF ANY RIGHTS GRANTED TO YOU FOR THE CODE, CLOUDERA IS NOT LIABLE FOR ANY
#  DIRECT, INDIRECT, INCIDENTAL, SPECIAL, EXEMPLARY, PUNITIVE OR
#  CONSEQUENTIAL DAMAGES INCLUDING, BUT NOT LIMITED TO, DAMAGES
#  RELATED TO LOST REVENUE, LOST PROFITS, LOSS OF INCOME, LOSS OF
#  BUSINESS ADVANTAGE OR UNAVAILABILITY, OR LOSS OR CORRUPTION OF
#  DATA.
#
# #  Author(s): Paul de Fusco
#***************************************************************************/

# %%
# !pip3 install open-inference-openapi
# Out:
# Collecting open-inference-openapi
#   Downloading open_inference_openapi-2.0.0.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/site-packages (from open-inference-openapi) (0.27.0)
# Requirement already satisfied: pydantic>1 in /usr/local/lib/python3.10/site-packages (from open-inference-openapi) (2.11.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (4.7.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.10/site-packages (from httpcore==1.*->httpx->open-inference-openapi) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/site-packages (from anyio->httpx->open-inference-openapi) (1.2.2)
# Downloading open_inference_openapi-2.0.0.1-py3-none-any.whl (29 kB)
# Installing collected packages: open-inference-openapi
# Successfully installed open-inference-openapi-2.0.0.1

# %%
#****************************************************************************
# (C) Cloudera, Inc. 2020-2023
#  All rights reserved.
#
#  Applicable Open Source License: GNU Affero General Public License v3.0
#
#  NOTE: Cloudera open source products are modular software products
#  made up of hundreds of individual components, each of which was
#  individually copyrighted.  Each Cloudera open source product is a
#  collective work under U.S. Copyright Law. Your license to use the
#  collective work is as provided in your written agreement with
#  Cloudera.  Used apart from the collective work, this file is
#  licensed for your use pursuant to the open source license
#  identified above.
#
#  This code is provided to you pursuant a written agreement with
#  (i) Cloudera, Inc. or (ii) a third-party authorized to distribute
#  this code. If you do not have a written agreement with Cloudera nor
#  with an authorized and properly licensed third party, you do not
#  have any rights to access nor to use this code.
#
#  Absent a written agreement with Cloudera, Inc. (“Cloudera”) to the
#  contrary, A) CLOUDERA PROVIDES THIS CODE TO YOU WITHOUT WARRANTIES OF ANY
#  KIND; (B) CLOUDERA DISCLAIMS ANY AND ALL EXPRESS AND IMPLIED
#  WARRANTIES WITH RESPECT TO THIS CODE, INCLUDING BUT NOT LIMITED TO
#  IMPLIED WARRANTIES OF TITLE, NON-INFRINGEMENT, MERCHANTABILITY AND
#  FITNESS FOR A PARTICULAR PURPOSE; (C) CLOUDERA IS NOT LIABLE TO YOU,
#  AND WILL NOT DEFEND, INDEMNIFY, NOR HOLD YOU HARMLESS FOR ANY CLAIMS
#  ARISING FROM OR RELATED TO THE CODE; AND (D)WITH RESPECT TO YOUR EXERCISE
#  OF ANY RIGHTS GRANTED TO YOU FOR THE CODE, CLOUDERA IS NOT LIABLE FOR ANY
#  DIRECT, INDIRECT, INCIDENTAL, SPECIAL, EXEMPLARY, PUNITIVE OR
#  CONSEQUENTIAL DAMAGES INCLUDING, BUT NOT LIMITED TO, DAMAGES
#  RELATED TO LOST REVENUE, LOST PROFITS, LOSS OF INCOME, LOSS OF
#  BUSINESS ADVANTAGE OR UNAVAILABILITY, OR LOSS OR CORRUPTION OF
#  DATA.
#
# #  Author(s): Paul de Fusco
#***************************************************************************/

# %%
# Import inference-related libraries
import httpx
import json
import time
import os
import subprocess
from urllib.parse import urlparse, urlunparse
from typing import Optional, Dict, Any, List

# Used while configuring CDP credentials config
import getpass
from llmopsUtils import *
# Out:
# CDP config function defined!

# %%
# !pip3 install --upgrade cdpcli
# Out:
# Collecting cdpcli
#   Downloading cdpcli-0.9.154.tar.gz (362 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/site-packages (from cdpcli) (2.8.2)
# Collecting docutils>=0.14 (from cdpcli)
#   Downloading docutils-0.22.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml>=3.11 in /usr/local/lib/python3.10/site-packages (from cdpcli) (6.0)
# Requirement already satisfied: colorama!=0.3.8,!=0.3.9,!=0.4.2,>=0.2.5 in /usr/local/lib/python3.10/site-packages (from cdpcli) (0.4.6)
# Collecting asn1crypto>=0.21.1 (from cdpcli)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: rsa>=3.4.2 in /runtime-addons/cmladdon-2.0.53-b273/opt/cmladdons/python/site-packages (from cdpcli) (4.9)
# Collecting pure25519>=0.0.1 (from cdpcli)
#   Downloading pure25519-0.0.1.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ecdsa>=0.17.0 (from cdpcli)
#   Downloading ecdsa-0.19.1-py2.py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/site-packages (from cdpcli) (2.32.3)
# Requirement already satisfied: urllib3>=1.21.1 in /home/cdsw/.local/lib/python3.10/site-packages (from cdpcli) (1.26.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->cdpcli) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests>=2.21.0->cdpcli) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests>=2.21.0->cdpcli) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/site-packages (from requests>=2.21.0->cdpcli) (2024.7.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /runtime-addons/cmladdon-2.0.53-b273/opt/cmladdons/python/site-packages (from rsa>=3.4.2->cdpcli) (0.6.1)
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
# Downloading docutils-0.22.4-py3-none-any.whl (633 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.2/633.2 kB 3.7 MB/s  0:00:00
# Downloading ecdsa-0.19.1-py2.py3-none-any.whl (150 kB)
# Building wheels for collected packages: cdpcli, pure25519
#   Building wheel for cdpcli (pyproject.toml) ... done
#   Created wheel for cdpcli: filename=cdpcli-0.9.154-py3-none-any.whl size=398669 sha256=e7f1abb9b58e25ab7c9c2fbaad8856ae063e8a7057f42f4e1f4a33ea2f033e56
#   Stored in directory: /home/cdsw/.cache/pip/wheels/22/28/7f/10347c7f3a917a8be6215ca89f1ea0e42e8490f3ba3370b348
#   Building wheel for pure25519 (pyproject.toml) ... done
#   Created wheel for pure25519: filename=pure25519-0.0.1-py3-none-any.whl size=24523 sha256=5528f4dc5c0089dd3ff4c24ba31a6119b1f2fda9b6019c7a394ab80396de9b7a
#   Stored in directory: /home/cdsw/.cache/pip/wheels/55/4a/1d/f5a7893255e176c67ba1858eb15949e16a7e5a9d309ebb90ff
# Successfully built cdpcli pure25519
# Installing collected packages: pure25519, asn1crypto, ecdsa, docutils, cdpcli
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [cdpcli]2m4/5 [cdpcli]s]o]
# Successfully installed asn1crypto-1.5.1 cdpcli-0.9.154 docutils-0.22.4 ecdsa-0.19.1 pure25519-0.0.1

# %%
# Configure CDP control plane credentials
access_key_id = getpass.getpass("Enter your CDP access key ID: ")
private_key = getpass.getpass("Enter your CDP private key: ")
configure_cdp("cdp_access_key_id", access_key_id)
configure_cdp("cdp_private_key", private_key)
# Out:
# Enter your CDP access key ID:  ········
# Enter your CDP private key:  ········

# %%
ENVIRONMENT_NAME = "go01-demo-aws"

CAII_DOMAIN = get_caii_domain(ENVIRONMENT_NAME)
CDP_TOKEN = get_ums_jwt_token()
print("CAI DOMAIN: ", CAII_DOMAIN)
print("CDP TOKEN: ", CDP_TOKEN)
# Out:
# CAI DOMAIN:  ml-64288d82-5dd.go01-dem.ylcu-atmi.cloudera.site
# CDP TOKEN:  eyJraWQiOiIzYzhlNzA3OTEyZmI0NTA1ODE3NzE3YzMyOTU4MmQwMTFjYjlmNTAwIiwidHlwIjoiSldUIiwiYWxnIjoiUlMyNTYifQ.....JsWxSFIztHBKGV7UymW8EIs_ip6m6n_Q7EqD-UJOQhna-JhcMfa1C1Ak7-qcwEV6XrJhF8WFHTGOsegbfcp-6ZMe0_7-Uz-Mxvo99Q-DB34XDi4cwAxSiktgEa3-SpU7nVLG16cFAV0E_sQZu_c3_9us2Wsz1pddTPHfN4BXxGZt1jusd5x1ih_oMGrWE_Qm7DiDTw0Pzwchgof6WjhAJ6EsRbNyJ1lSzbZdaBKp8qWfP7lSeUrBLk0QGQkeqEP5WlSPzgUtUPhSfXxEWmeQA4HS1ert6sovYAmPX0YFswkTDJdiSpIf-Q-Xj_Mn0GV8TZCjnsV4xohjanz_MjVKPg

# %%
REGISTRY_ENDPOINT = get_registry_endpoint(ENVIRONMENT_NAME)
print("REGISTRY ENDPOINT: ", REGISTRY_ENDPOINT)
# Out:
# REGISTRY ENDPOINT:  https://modelregistry.ml-889f4fff-5e8.go01-dem.ylcu-atmi.cloudera.site

# %%
REGISTERED_MODEL_NAME = "fraud-detector-onnx-xgboost"

model_details = get_model_details(REGISTRY_ENDPOINT, REGISTERED_MODEL_NAME, CDP_TOKEN)
print(model_details)
# Out:
# {'created_at': '2025-03-20T22:31:10.356Z', 'creator': {'user_name': 'pauldefusco'}, 'id': '3yss-zkky-xrp6-i51n', 'name': 'fraud-detector-onnx-xgboost', 'tags': None, 'updated_at': '2025-03-20T22:31:10.356Z', 'visibility': 'public'}

# %%
MODEL_VERSION = get_most_recent_model_version(REGISTRY_ENDPOINT, model_details['id'], CDP_TOKEN)

MODEL_ID = model_details['id']
print(MODEL_ID)
print(MODEL_VERSION)
# Out:
# 3yss-zkky-xrp6-i51n
# 5

# %%
ENDPOINT_NAME = "xgboost-endpoint"
deploy_model_to_caii(CAII_DOMAIN, CDP_TOKEN, MODEL_ID, MODEL_VERSION, ENDPOINT_NAME)
# Out:
# Deployed xgboost-endpoint successfully!

# %%
# Must return True before we go on to the next step
ready = endpoint_is_ready(CAII_DOMAIN, CDP_TOKEN, ENDPOINT_NAME)
print(ready)
# Out:
# True

# %%
BASE_URL = get_endpoint_base_url(CAII_DOMAIN, CDP_TOKEN, ENDPOINT_NAME)
print(BASE_URL)
# Out:
# https://ml-64288d82-5dd.go01-dem.ylcu-atmi.cloudera.site/namespaces/serving-default/endpoints/xgboost-endpoint

# %% [markdown]
# ### Inference

# %%
import os, warnings, sys, logging
import mlflow
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score
import mlflow.sklearn
from xgboost import XGBClassifier
from datetime import date
import cml.data_v1 as cmldata
import pyspark.pandas as ps

USERNAME = os.environ["PROJECT_OWNER"]
DBNAME = "BANK"+"_"+USERNAME
CONNECTION_NAME = "go01-aw-dl"

DATE = date.today()
EXPERIMENT_NAME = "xgb-cc-fraud-{0}".format(USERNAME)

mlflow.set_experiment(EXPERIMENT_NAME)

conn = cmldata.get_connection(CONNECTION_NAME)
spark = conn.get_spark_session()

df_from_sql = ps.read_table('{0}.CC_TRX_{1}'.format(DBNAME, USERNAME))
df = df_from_sql.to_pandas()
#df = df.drop(columns=["job"])

test_size = 0.3
X_train, X_test, y_train, y_test = train_test_split(df.drop("fraud_trx", axis=1), df["fraud_trx"], test_size=test_size)
# Out:
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
# Setting spark.hadoop.yarn.resourcemanager.principal to pauldefusco
# Spark Application Id:spark-299360a7c82c439292aed3b5f5390c43
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: If `index_col` is not specified for `read_table`, the default index is attached which can cause additional overhead.
# Hive Session ID = 3224123e-56d3-4022-89c4-4931ff2438c2
# /opt/spark/python/lib/pyspark.zip/pyspark/pandas/utils.py:1016: PandasAPIOnSparkAdviceWarning: `to_pandas` loads all data into the driver's memory. It should only be used if the resulting pandas DataFrame is expected to be small.

# %%
# !pip3 install open-inference-openapi tritonclient[all]
# Out:
# Requirement already satisfied: open-inference-openapi in /home/cdsw/.local/lib/python3.10/site-packages (2.0.0.1)
# Collecting tritonclient[all]
#   Downloading tritonclient-2.65.0-py3-none-manylinux1_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/site-packages (from open-inference-openapi) (0.27.0)
# Requirement already satisfied: pydantic>1 in /usr/local/lib/python3.10/site-packages (from open-inference-openapi) (2.11.10)
# Requirement already satisfied: numpy>=1.19.1 in /usr/local/lib/python3.10/site-packages (from tritonclient[all]) (1.26.4)
# Collecting python-rapidjson>=0.9.1 (from tritonclient[all])
#   Downloading python_rapidjson-1.23-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (24 kB)
# Collecting urllib3>=2.0.7 (from tritonclient[all])
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/site-packages (from tritonclient[all]) (3.12.14)
# Collecting cuda-python (from tritonclient[all])
#   Downloading cuda_python-13.1.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting geventhttpclient>=2.3.3 (from tritonclient[all])
#   Downloading geventhttpclient-2.3.7-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Collecting grpcio<1.68,>=1.63.0 (from tritonclient[all])
#   Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging>=14.1 in /usr/local/lib/python3.10/site-packages (from tritonclient[all]) (23.2)
# Collecting perf-analyzer (from tritonclient[all])
#   Downloading perf_analyzer-2.59.1-py3-none-manylinux_2_38_x86_64.whl.metadata (6.3 kB)
# Collecting protobuf<6.0dev,>=5.26.1 (from tritonclient[all])
#   Downloading protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (6.0.5)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (1.20.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (3.7)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.10/site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.8.1->tritonclient[all]) (4.12.2)
# Collecting gevent (from geventhttpclient>=2.3.3->tritonclient[all])
#   Downloading gevent-25.9.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/site-packages (from geventhttpclient>=2.3.3->tritonclient[all]) (2024.7.4)
# Collecting brotli (from geventhttpclient>=2.3.3->tritonclient[all])
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.10/site-packages (from pydantic>1->open-inference-openapi) (0.4.2)
# Collecting cuda-bindings~=13.1.1 (from cuda-python->tritonclient[all])
#   Downloading cuda_bindings-13.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting cuda-pathfinder~=1.1 (from cuda-python->tritonclient[all])
#   Downloading cuda_pathfinder-1.3.4-py3-none-any.whl.metadata (1.9 kB)
# Collecting greenlet>=3.2.2 (from gevent->geventhttpclient>=2.3.3->tritonclient[all])
#   Downloading greenlet-3.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Collecting zope.event (from gevent->geventhttpclient>=2.3.3->tritonclient[all])
#   Downloading zope_event-6.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting zope.interface (from gevent->geventhttpclient>=2.3.3->tritonclient[all])
#   Downloading zope_interface-8.2-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (45 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (4.7.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (1.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/site-packages (from httpx->open-inference-openapi) (1.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.10/site-packages (from httpcore==1.*->httpx->open-inference-openapi) (0.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/site-packages (from anyio->httpx->open-inference-openapi) (1.2.2)
# Downloading tritonclient-2.65.0-py3-none-manylinux1_x86_64.whl (111 kB)
# Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 12.4 MB/s  0:00:00m0:00:0100:01
# Downloading protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl (320 kB)
# Downloading geventhttpclient-2.3.7-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (114 kB)
# Downloading python_rapidjson-1.23-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.9 MB/s  0:00:00 eta 0:00:01
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.6 MB/s  0:00:00
# Downloading cuda_python-13.1.1-py3-none-any.whl (8.0 kB)
# Downloading cuda_bindings-13.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 15.0 MB/s  0:00:01m0:00:0100:01
# Downloading cuda_pathfinder-1.3.4-py3-none-any.whl (30 kB)
# Downloading gevent-25.9.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.3 MB/s  0:00:00 eta 0:00:01
# Downloading greenlet-3.3.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.0/587.0 kB 2.2 MB/s  0:00:00 eta 0:00:01
# Downloading perf_analyzer-2.59.1-py3-none-manylinux_2_38_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 29.1 MB/s  0:00:006m0:00:01
# Downloading zope_event-6.1-py3-none-any.whl (6.4 kB)
# Downloading zope_interface-8.2-cp310-cp310-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (254 kB)
# Installing collected packages: perf-analyzer, brotli, zope.interface, zope.event, urllib3, python-rapidjson, protobuf, grpcio, greenlet, cuda-pathfinder, tritonclient, gevent, cuda-bindings, geventhttpclient, cuda-python
#   Attempting uninstall: urllib3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/15 [zope.event]ace]
#     Found existing installation: urllib3 1.26.20━━━━━━━━━━━━━━  3/15 [zope.event]
#     Uninstalling urllib3-1.26.20:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/15 [urllib3]
#       Successfully uninstalled urllib3-1.26.20━━━━━━━━━━━━━━━━  4/15 [urllib3]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [cuda-python] [cuda-python]ient]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.20.112 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.6.3 which is incompatible.
# raz-client 1.1.0 requires boto3>=1.23.10, but you have boto3 1.17.62 which is incompatible.
# raz-client 1.1.0 requires protobuf==4.25.3, but you have protobuf 5.29.6 which is incompatible.
# raz-client 1.1.0 requires requests-kerberos>=0.14.0, but you have requests-kerberos 0.12.0 which is incompatible.
# mlflow-cml-plugin 0.0.1 requires protobuf==4.25.3, but you have protobuf 5.29.6 which is incompatible.
# mlflow-cml-plugin 0.0.1 requires typing-extensions==4.10.0, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed brotli-1.2.0 cuda-bindings-13.1.1 cuda-pathfinder-1.3.4 cuda-python-13.1.1 gevent-25.9.1 geventhttpclient-2.3.7 greenlet-3.3.1 grpcio-1.67.1 perf-analyzer-2.59.1 protobuf-5.29.6 python-rapidjson-1.23 tritonclient-2.65.0 urllib3-2.6.3 zope.event-6.1 zope.interface-8.2

# %%
BASE_URL = 'https://ml-64288d82-5dd.go01-dem.ylcu-atmi.cloudera.site/namespaces/serving-default/endpoints/xgboost-endpoint'

headers = {
	'Authorization': 'Bearer ' + CDP_TOKEN,
	'Content-Type': 'application/json'
}

httpx_client = httpx.Client(headers=headers)
client = OpenInferenceClient(base_url=BASE_URL, httpx_client=httpx_client)

# Check that the server is live, and it has the model loaded
client.check_server_readiness()
metadata = client.read_model_metadata(MODEL_NAME)
metadata_str = json.dumps(json.loads(metadata.json()), indent=2)
print(metadata_str)
# Out:
# {
#   "name": "3yss-zkky-xrp6-i51n",
#   "versions": [
#     "5"
#   ],
#   "platform": "onnxruntime_onnx",
#   "inputs": [
#     {
#       "name": "input",
#       "datatype": "FP32",
#       "shape": [
#         -1,
#         14
#       ]
#     }
#   ],
#   "outputs": [
#     {
#       "name": "probabilities",
#       "datatype": "FP32",
#       "shape": [
#         -1,
#         2
#       ]
#     },
#     {
#       "name": "label",
#       "datatype": "INT64",
#       "shape": [
#         -1,
#         1
#       ]
#     }
#   ]
# }

# %%
import time

data = X_train.iloc[0].values.tolist()
payload = {
    "parameters": {
        "content_type": "pd"
    },
    "inputs": [
        {
            "name": "input",
            "datatype": "FP32",
            "shape": [1, 14],
            "data": data
        }
    ]
}
start = time.time()
pred = client.model_infer(
    MODEL_ID,
    request=InferenceRequest(
        inputs=payload["inputs"]
    ),
)

end = time.time()

json_resp_str = json.dumps(json.loads(pred.json()), indent=2)
print(json_resp_str)
print(f"latency={end-start}")
# Out:
# {
#   "model_name": "3yss-zkky-xrp6-i51n",
#   "model_version": "5",
#   "outputs": [
#     {
#       "name": "label",
#       "shape": [
#         1,
#         1
#       ],
#       "datatype": "INT64",
#       "data": [
#         0.0
#       ]
#     },
#     {
#       "name": "probabilities",
#       "shape": [
#         1,
#         2
#       ],
#       "datatype": "FP32",
#       "data": [
#         0.993344783782959,
#         0.006655216217041016
#       ]
#     }
#   ]
# }
# latency=0.0379643440246582
